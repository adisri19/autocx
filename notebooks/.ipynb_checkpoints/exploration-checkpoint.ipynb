# %% [markdown]
# # Autocw AI Customer Support Agent — Exploration Notebook
#
# This notebook demonstrates:
# 1. **Brand Volume Analysis**: Exploring inbound/outbound volume across brands in `twcs.csv`.
# 2. **Thread Reconstruction**: Multi-turn dialogue graph traversal.
# 3. **Text Cleaning & Sanitization**: Twitter mentions, links, and entity removal.
# 4. **Intent Clustering & Taxonomy**: BERTopic / K-Means keyword analysis.
# 5. **Semantic Retrieval & RAG**: MiniLM vector search and response drafting.
# 6. **Hybrid Escalation**: Deterministic rules and borderline reasoning.

# %%
import os
import pandas as pd
import json
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/adityasrivastava/Desktop/autocw/data/raw/twcs.csv', low_memory=False)
print("Working dir:", os.getcwd())
# Out:
# Working dir: /Users/adityasrivastava/Desktop/autocw

# %%
# Brand volume chart
df = pd.read_csv('/Users/adityasrivastava/Desktop/autocw/data/raw/twcs.csv', low_memory=False)
brand_counts = df[df['inbound'] == False]['author_id'].value_counts().head(10)
brand_counts.plot(kind='bar', figsize=(12,5), title='Top 10 Brands by Reply Volume')
plt.tight_layout()
plt.show()

# %%
# Sample threads
with open('/Users/adityasrivastava/Desktop/autocw/data/processed/conversations.jsonl') as f:
    threads = [json.loads(l) for l in f]

# Show 3 sample threads
for t in threads[:3]:
    print(f"\n--- Thread {t['thread_id']} ---")
    for turn in t['turns']:
        print(f"[{turn['role'].upper()}]: {turn['text'][:100]}")
# Out:
# --- Thread thread_2960462 ---
# [CUSTOMER]: Prime used to mean I'd get what I ordered in two days. Not so much anymore. 3, 4, 5, days seems to b
# [AGENT]: I'm sorry for the wait! Have we missed the delivery date shown in your order confirmation e-mail? Is
# [CUSTOMER]: re-read my tweet
# [AGENT]: Two-Day refers to the time it takes once it ships. Some items require additional processing time, we
#
# --- Thread thread_424000 ---
# [CUSTOMER]: Replacement Order : 408-5489419-9601966 my refund have not yet been initiate will your team make it
# [AGENT]: Please don't provide your order details, we consider it to be personal information. Our page is visi
#
# --- Thread thread_130289 ---
# [CUSTOMER]: Well what a surprise my package wasnt sent despite it claiming to have arrived in my town. Wow. Just
# [AGENT]: I'm sorry you haven't yet received your package. We're here to help! Please let us know if this orde

# %%
with open('/Users/adityasrivastava/Desktop/autocw/data/processed/conversations.jsonl') as f:
    threads = [json.loads(l) for l in f]

for t in threads[:3]:
    print(f"\n--- Thread {t['thread_id']} ---")
    for turn in t['turns']:
        print(f"[{turn['role'].upper()}]: {turn['text'][:100]}")
# Out:
# --- Thread thread_2960462 ---
# [CUSTOMER]: Prime used to mean I'd get what I ordered in two days. Not so much anymore. 3, 4, 5, days seems to b
# [AGENT]: I'm sorry for the wait! Have we missed the delivery date shown in your order confirmation e-mail? Is
# [CUSTOMER]: re-read my tweet
# [AGENT]: Two-Day refers to the time it takes once it ships. Some items require additional processing time, we
#
# --- Thread thread_424000 ---
# [CUSTOMER]: Replacement Order : 408-5489419-9601966 my refund have not yet been initiate will your team make it
# [AGENT]: Please don't provide your order details, we consider it to be personal information. Our page is visi
#
# --- Thread thread_130289 ---
# [CUSTOMER]: Well what a surprise my package wasnt sent despite it claiming to have arrived in my town. Wow. Just
# [AGENT]: I'm sorry you haven't yet received your package. We're here to help! Please let us know if this orde

# %%
import os
os.chdir('/Users/adityasrivastava/Desktop/autocw')
import json
from pathlib import Path
import pandas as pd
import numpy as np
from src.config import PROJECT_ROOT, RAW_DATASET_FILE, CONVERSATIONS_FILE, QUERY_REPLY_PAIRS_FILE
from src.utils.text import clean_tweet_text
from src.pipeline import process_message

# %% [markdown]
# ## 1. Brand Volume Analysis in `twcs.csv`

# %%
if RAW_DATASET_FILE.exists():
    df = pd.read_csv(RAW_DATASET_FILE, nrows=500000, low_memory=False)
    outbound = df[df['inbound'] == False]
    brand_counts = outbound['author_id'].value_counts().head(10)
    print("Top 10 Support Handles by Outbound Volume (Sampled):")
    print(brand_counts)
else:
    print("twcs.csv not found at data/raw/twcs.csv")
# Out:
# Top 10 Support Handles by Outbound Volume (Sampled):
# author_id
# AmazonHelp         42944
# AppleSupport       15694
# Uber_Support       10367
# Delta               7380
# AmericanAir         6593
# SpotifyCares        6423
# British_Airways     5411
# comcastcares        5232
# XboxSupport         5123
# TMobileHelp         4744
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Reconstructed Thread Inspection

# %%
if CONVERSATIONS_FILE.exists():
    with open(CONVERSATIONS_FILE, 'r', encoding='utf-8') as f:
        sample_thread = json.loads(f.readline())
    
    print(f"Thread ID: {sample_thread['thread_id']}")
    print(f"Brand: {sample_thread['brand']}")
    print("\nDialogue Turns:")
    for i, turn in enumerate(sample_thread['turns'], 1):
        print(f"  [{i}] ({turn['role'].upper()} - {turn['author_id']}): {turn['text']}")
# Out:
# Thread ID: thread_2960462
# Brand: AmazonHelp
#
# Dialogue Turns:
#   [1] (CUSTOMER - 476214): Prime used to mean I'd get what I ordered in two days. Not so much anymore. 3, 4, 5, days seems to be the new normal.
#   [2] (AGENT - AmazonHelp): I'm sorry for the wait! Have we missed the delivery date shown in your order confirmation e-mail? Is there a current order past the date shown in that e-mail? You can check here: ^JM
#   [3] (CUSTOMER - 476214): re-read my tweet
#   [4] (AGENT - AmazonHelp): Two-Day refers to the time it takes once it ships. Some items require additional processing time, we'll include that into the date given. Please let us know if we ever miss the date given during checkout. ^LI

# %% [markdown]
# ## 3. Query-Reply Semantic Retrieval

# %%
from src.drafter.draft import retrieve_similar

test_query = "My package has been delayed for three days and tracking has not moved."
matches = retrieve_similar(test_query, top_k=3)
print(f"Query: {test_query}\n")
for idx, m in enumerate(matches, 1):
    print(f"--- Match {idx} (Similarity: {m['score']:.3f}) ---")
    print(f"Historical Customer: {m['query']}")
    print(f"Historical Agent:    {m['reply']}\n")
# Out:
# 2026-09-10 12:33:28,368 [INFO] Loaded embedding index containing 5,000 entries.
# 2026-09-10 12:33:28,369 [INFO] Loading embedding model all-MiniLM-L6-v2 on CPU...
# 2026-09-10 12:33:28,704 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-10 12:33:28,706 [WARNING] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-10 12:33:28,735 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/modules.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fmodules.json=&etag=%22952a9b81c0bfd99800fabf352f69c7ccd46c5e43%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:28,973 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:29,003 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config_sentence_transformers.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fconfig_sentence_transformers.json=&etag=%22fd1b291129c607e5d49799f87cb219b27f98acdf%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:29,008 [INFO] Loading SentenceTransformer model from sentence-transformers/all-MiniLM-L6-v2.
# 2026-09-10 12:33:29,246 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:29,283 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config_sentence_transformers.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fconfig_sentence_transformers.json=&etag=%22fd1b291129c607e5d49799f87cb219b27f98acdf%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:29,535 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:29,565 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/README.md?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2FREADME.md=&etag=%2244af2e3b0fa3a0b6239e48422972bf755f28fde0%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:29,814 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:29,847 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/modules.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fmodules.json=&etag=%22952a9b81c0bfd99800fabf352f69c7ccd46c5e43%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:30,107 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:30,141 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/sentence_bert_config.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fsentence_bert_config.json=&etag=%2259d594003bf59880a884c574bf88ef7555bb0202%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:30,608 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:30,863 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:30,930 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fconfig.json=&etag=%2272b987fd805cfa2b58c4c8c952b274a11bfd5a00%22 "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# 2026-09-10 12:33:31,299 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:31,560 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:31,811 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:32,051 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:32,331 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:32,381 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/tokenizer_config.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Ftokenizer_config.json=&etag=%22c79f2b6a0cea6f4b564fed1938984bace9d30ff0%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:32,612 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:32,649 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fconfig.json=&etag=%2272b987fd805cfa2b58c4c8c952b274a11bfd5a00%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:32,890 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:32,922 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Fconfig.json=&etag=%2272b987fd805cfa2b58c4c8c952b274a11bfd5a00%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:33,167 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:33,206 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/tokenizer_config.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2Ftokenizer_config.json=&etag=%22c79f2b6a0cea6f4b564fed1938984bace9d30ff0%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:33,480 [INFO] HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:33,712 [INFO] HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-09-10 12:33:33,985 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-09-10 12:33:34,020 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/1_Pooling%2Fconfig.json?%2Fsentence-transformers%2Fall-MiniLM-L6-v2%2Fresolve%2Fmain%2F1_Pooling%2Fconfig.json=&etag=%22d1514c3162bbe87b343f565fadc62e6c06f04f03%22 "HTTP/1.1 200 OK"
# 2026-09-10 12:33:34,265 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/2_Normalize/config.json "HTTP/1.1 404 Not Found"
# 2026-09-10 12:33:34,550 [INFO] HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2 "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Query: My package has been delayed for three days and tracking has not moved.
#
# --- Match 1 (Similarity: 0.755) ---
# Historical Customer: I am not able to track my package. Can you help please ?
# Historical Agent:    You can track your package here: ^SH
#
# --- Match 2 (Similarity: 0.704) ---
# Historical Customer: product not delivered and tracking status showing..Delivery delayed on customer request..No request made for delay delivery
# Historical Agent:    I'm sorry for any confusion. Please connect with our support team here: for assistance on it. ^RW
#
# --- Match 3 (Similarity: 0.662) ---
# Historical Customer: Why I hate not getting tracking info from Amazon: package was supposed to arrive yesterday and still hasn't
# Historical Agent:    We're sorry to hear this! We'd like to lend you a hand; what does the current order status show: ^WM

# %% [markdown]
# ## 4. End-to-End Agent Execution

# %%
queries = [
    "Where can I check the estimated arrival date of my order?",
    "I returned the defective boots last Monday, when will I get my money back?",
    "If you do not refund my money today, I am going to have my lawyer file a lawsuit!"
]

for q in queries:
    res = process_message(q)
    print("=" * 70)
    print(f"Customer: {q}")
    print(f"Intent:   {res['intent']} (confidence: {res['confidence']})")
    print(f"Escalate: {res['escalate']} (reason: {res['escalation_reason']})")
    print(f"Draft:    {res['draft_reply']}")
# Out:
# 2026-09-10 12:33:40,453 [INFO] HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-09-10 12:33:41,048 [INFO] HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# ======================================================================
# Customer: Where can I check the estimated arrival date of my order?
# Intent:   ORDER_STATUS (confidence: 0.98)
# Escalate: False (reason: None)
# Draft:    I understand you are looking for your order's estimated arrival date. Please log in to your account and navigate to the "Your Orders" section to view the specific delivery details for your purchase.
# 2026-09-10 12:33:42,106 [INFO] HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-09-10 12:33:42,716 [INFO] HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# ======================================================================
# Customer: I returned the defective boots last Monday, when will I get my money back?
# Intent:   REFUND_REQUEST (confidence: 0.98)
# Escalate: False (reason: None)
# Draft:    I’m sorry to hear about the defective boots, but please rest assured that your refund is being processed. You can track the specific timeline for your return and view the status of your refund here: ^WJ
# 2026-09-10 12:33:43,268 [INFO] HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-09-10 12:33:43,794 [INFO] HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# ======================================================================
# Customer: If you do not refund my money today, I am going to have my lawyer file a lawsuit!
# Intent:   REFUND_REQUEST (confidence: 0.95)
# Escalate: True (reason: Rule-based: Legal action or attorney threat detected)
# Draft:    I completely understand your frustration and take your concerns seriously. Please reach out to our support team via the link provided so we can investigate your case and process your refund as quickly as possible.
